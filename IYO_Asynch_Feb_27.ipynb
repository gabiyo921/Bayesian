# %% [markdown]
# <a href="https://colab.research.google.com/github/gabiyo921/Bayesian/blob/main/IYO_Asynch_Feb_27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **THE PRIOR**

# %%
import scipy.stats as sts
import numpy as np
import matplotlib.pyplot as plt

mu = np.linspace(1.65, 1.8, num=50)
test = np.linspace(0, 2)
uniform_dist = sts.uniform.pdf(mu) + 1

uniform_dist = uniform_dist/uniform_dist.sum()
beta_dist = sts.beta.pdf(mu, 2, 5, loc = 1.65, scale = 0.2)
beta_dist = beta_dist/beta_dist.sum()

plt.figure(figsize=(10, 6))
plt.plot(mu, beta_dist, label = 'Beta Dist')
plt.plot(mu, uniform_dist, label = 'Uniform Dist')
plt.xlabel("Value of $\mu$ in meters")
plt.ylabel("Probability density")
plt.legend()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-431/1544282593.py:16: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Value of $\mu$ in meters")

# %% [markdown]
# **THE LIKELIHOOD**

# %%
def likelihood_func(datum, mu):
  likelihood_out = sts.norm.pdf(datum, mu, scale = 0.1)
  return likelihood_out/likelihood_out.sum()

likelihood_out = likelihood_func(1.7, mu)

plt.plot(mu, likelihood_out)
plt.title("Likelihood of $\mu$ given observation 1.7m")
plt.ylabel("Probability Density/Likelihood")
plt.xlabel("Value of $\mu$")
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-431/3518573821.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.title("Likelihood of $\mu$ given observation 1.7m")
# /tmp/ipython-input-431/3518573821.py:10: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Value of $\mu$")

# %% [markdown]
# **THE POSTERIOR**

# %%
import scipy as sp

unnormalized_posterior = likelihood_out * uniform_dist
plt.plot(mu, unnormalized_posterior)
plt.xlabel("$\mu$ in meters")
plt.ylabel("Unnormalized Posterior")
plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-431/3529792179.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("$\mu$ in meters")

# %%
unnormalized_posterior.sum()
# Out:
# np.float64(0.019999999999999997)
